# %% [markdown]
# ## Importing python libraries

# %%
## Data Analysis libraries
import pandas as pd
import numpy as np

## Data Visualization Libraries
import matplotlib.pyplot as plt
import seaborn as sns

## Ignore warnings libraries
import warnings 
warnings.filterwarnings('ignore')

# %% [markdown]
# ## Importing datasets

# %%
bank = pd.read_csv(r'C:\Users\admin\Desktop\edyoda\files\Data wrangling\Churn.csv')
telco = pd.read_csv(r'C:\Users\admin\Desktop\edyoda\files\Data wrangling\customer_churn_data.csv')
stroke = pd.read_csv(r'C:\Users\admin\Desktop\edyoda\files\Data wrangling\strokes_data.csv')
house = pd.read_csv(r'C:\Users\admin\Desktop\edyoda\files\Data wrangling\kc_house_data.csv')
insurance = pd.read_csv(r'C:\Users\admin\Desktop\edyoda\files\Data wrangling\insurance.csv')
tips = pd.read_csv(r'C:\Users\admin\Desktop\edyoda\files\Data wrangling\tips.csv')

# %% [markdown]
# ## Display few lines of data

# %% [markdown]
# ## Display first 5 rows of 'bank' dataset

# %%
bank.head(5)
# Out:
#     Surname  CreditScore Geography  Gender  Age  Tenure    Balance  \
# 0  Hargrave          619    France       0   42       2       0.00
# 1      Hill          608     Spain       0   41       1   83807.86
# 2      Onio          502    France       0   42       8  159660.80
# 3      Boni          699    France       0   39       1       0.00
# 4  Mitchell          850     Spain       0   43       2  125510.82
#
#    NumOfProducts  HasCrCard  IsActiveMember  EstimatedSalary  Exited
# 0              1          1               1        101348.88       1
# 1              1          0               1        112542.58       0
# 2              3          1               0        113931.57       1
# 3              2          0               0         93826.63       0
# 4              1          1               1         79084.10       0

# %% [markdown]
# ## Display first 5 rows of 'telco' dataset

# %%
telco.head(5)
# Out:
#    customerID  gender  SeniorCitizen Partner Dependents  tenure PhoneService  \
# 0  7590-VHVEG  Female              0     Yes         No       1           No
# 1  5575-GNVDE    Male              0      No         No      34          Yes
# 2  3668-QPYBK    Male              0      No         No       2          Yes
# 3  7795-CFOCW    Male              0      No         No      45           No
# 4  9237-HQITU  Female              0      No         No       2          Yes
#
#       MultipleLines InternetService OnlineSecurity  ... DeviceProtection  \
# 0  No phone service             DSL             No  ...               No
# 1                No             DSL            Yes  ...              Yes
# 2                No             DSL            Yes  ...               No
# 3  No phone service             DSL            Yes  ...              Yes
# 4                No     Fiber optic             No  ...               No
#
#   TechSupport StreamingTV StreamingMovies        Contract PaperlessBilling  \
# 0          No          No              No  Month-to-month              Yes
# 1          No          No              No        One year               No
# 2          No          No              No  Month-to-month              Yes
# 3         Yes          No              No        One year               No
# 4          No          No              No  Month-to-month              Yes
#
#                PaymentMethod MonthlyCharges  TotalCharges Churn
# 0           Electronic check          29.85         29.85    No
# 1               Mailed check          56.95        1889.5    No
# 2               Mailed check          53.85        108.15   Yes
# 3  Bank transfer (automatic)          42.30       1840.75    No
# 4           Electronic check          70.70        151.65   Yes
#
# [5 rows x 21 columns]

# %% [markdown]
# ## Display first 5 rows of 'stroke' dataset

# %%
stroke.head(5)
# Out:
#        work_type   smoking_status  gender  ever_married  Residence_type   age  \
# 0        Private  formerly smoked       1             1               0  67.0
# 1  Self-employed     never smoked       0             1               1  61.0
# 2        Private     never smoked       1             1               1  80.0
# 3        Private           smokes       0             1               0  49.0
# 4  Self-employed     never smoked       0             1               1  79.0
#
#    hypertension  heart_disease  avg_glucose_level        bmi  stroke
# 0             0              1             228.69  36.600000       1
# 1             0              0             202.21  28.893237       1
# 2             0              1             105.92  32.500000       1
# 3             0              0             171.23  34.400000       1
# 4             1              0             174.12  24.000000       1

# %% [markdown]
# ## Display first 5 rows of 'house' dataset

# %%
house.head(5)
# Out:
#            id             date     price  bedrooms  bathrooms  sqft_living  \
# 0  7129300520  20141013T000000  221900.0         3       1.00         1180
# 1  6414100192  20141209T000000  538000.0         3       2.25         2570
# 2  5631500400  20150225T000000  180000.0         2       1.00          770
# 3  2487200875  20141209T000000  604000.0         4       3.00         1960
# 4  1954400510  20150218T000000  510000.0         3       2.00         1680
#
#    sqft_lot  floors  waterfront  view  ...  grade  sqft_above  sqft_basement  \
# 0      5650     1.0           0     0  ...      7        1180              0
# 1      7242     2.0           0     0  ...      7        2170            400
# 2     10000     1.0           0     0  ...      6         770              0
# 3      5000     1.0           0     0  ...      7        1050            910
# 4      8080     1.0           0     0  ...      8        1680              0
#
#    yr_built  yr_renovated  zipcode      lat     long  sqft_living15  \
# 0      1955             0    98178  47.5112 -122.257           1340
# 1      1951          1991    98125  47.7210 -122.319           1690
# 2      1933             0    98028  47.7379 -122.233           2720
# 3      1965             0    98136  47.5208 -122.393           1360
# 4      1987             0    98074  47.6168 -122.045           1800
#
#    sqft_lot15
# 0        5650
# 1        7639
# 2        8062
# 3        5000
# 4        7503
#
# [5 rows x 21 columns]

# %% [markdown]
# ## Display first 5 rows of 'insurance' dataset

# %%
insurance.head(5)
# Out:
#    index  age     sex     bmi  children smoker     region      charges
# 0      0   19  female  27.900         0    yes  southwest  16884.92400
# 1      1   18    male  33.770         1     no  southeast   1725.55230
# 2      2   28    male  33.000         3     no  southeast   4449.46200
# 3      3   33    male  22.705         0     no  northwest  21984.47061
# 4      4   32    male  28.880         0     no  northwest   3866.85520

# %% [markdown]
# ## Display size of the data

# %% [markdown]
# ## Display the size of 'bank','telco','stroke','house' and 'insurance' datasets

# %%
print("bank :", bank.shape)
print("telco :", telco.shape)
print("stroke :", stroke.shape)
print("house :", house.shape)
print("insurance :", insurance.shape)
# Out:
# bank : (10000, 12)
# telco : (7043, 21)
# stroke : (5110, 11)
# house : (21613, 21)
# insurance : (1338, 8)

# %% [markdown]
# ## Display Information

# %% [markdown]
# ## Display information (fields, datatypes, null values etc) about 'bank' dataset

# %%
bank.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10000 entries, 0 to 9999
# Data columns (total 12 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Surname          10000 non-null  object
#  1   CreditScore      10000 non-null  int64
#  2   Geography        10000 non-null  object
#  3   Gender           10000 non-null  int64
#  4   Age              10000 non-null  int64
#  5   Tenure           10000 non-null  int64
#  6   Balance          10000 non-null  float64
#  7   NumOfProducts    10000 non-null  int64
#  8   HasCrCard        10000 non-null  int64
#  9   IsActiveMember   10000 non-null  int64
#  10  EstimatedSalary  10000 non-null  float64
#  11  Exited           10000 non-null  int64
# dtypes: float64(2), int64(8), object(2)
# memory usage: 937.6+ KB

# %% [markdown]
# ## Display information (fields, datatypes, null values etc) about 'telco' dataset

# %%
telco.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7043 entries, 0 to 7042
# Data columns (total 21 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   customerID        7043 non-null   object
#  1   gender            7043 non-null   object
#  2   SeniorCitizen     7043 non-null   int64
#  3   Partner           7043 non-null   object
#  4   Dependents        7043 non-null   object
#  5   tenure            7043 non-null   int64
#  6   PhoneService      7043 non-null   object
#  7   MultipleLines     7043 non-null   object
#  8   InternetService   7043 non-null   object
#  9   OnlineSecurity    7043 non-null   object
#  10  OnlineBackup      7043 non-null   object
#  11  DeviceProtection  7043 non-null   object
#  12  TechSupport       7043 non-null   object
#  13  StreamingTV       7043 non-null   object
#  14  StreamingMovies   7043 non-null   object
#  15  Contract          7043 non-null   object
#  16  PaperlessBilling  7043 non-null   object
#  17  PaymentMethod     7043 non-null   object
#  18  MonthlyCharges    7043 non-null   float64
#  19  TotalCharges      7043 non-null   object
#  20  Churn             7043 non-null   object
# dtypes: float64(1), int64(2), object(18)
# memory usage: 1.1+ MB

# %% [markdown]
# ## Display information (fields, datatypes, null values etc) about 'stroke' dataset

# %%
stroke.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5110 entries, 0 to 5109
# Data columns (total 11 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   work_type          5110 non-null   object
#  1   smoking_status     5110 non-null   object
#  2   gender             5110 non-null   int64
#  3   ever_married       5110 non-null   int64
#  4   Residence_type     5110 non-null   int64
#  5   age                5110 non-null   float64
#  6   hypertension       5110 non-null   int64
#  7   heart_disease      5110 non-null   int64
#  8   avg_glucose_level  5110 non-null   float64
#  9   bmi                5110 non-null   float64
#  10  stroke             5110 non-null   int64
# dtypes: float64(3), int64(6), object(2)
# memory usage: 439.3+ KB

# %% [markdown]
# ## Display information (fields, datatypes, null values etc) about 'house' dataset

# %%
house.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 21613 entries, 0 to 21612
# Data columns (total 21 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   id             21613 non-null  int64
#  1   date           21613 non-null  object
#  2   price          21613 non-null  float64
#  3   bedrooms       21613 non-null  int64
#  4   bathrooms      21613 non-null  float64
#  5   sqft_living    21613 non-null  int64
#  6   sqft_lot       21613 non-null  int64
#  7   floors         21613 non-null  float64
#  8   waterfront     21613 non-null  int64
#  9   view           21613 non-null  int64
#  10  condition      21613 non-null  int64
#  11  grade          21613 non-null  int64
#  12  sqft_above     21613 non-null  int64
#  13  sqft_basement  21613 non-null  int64
#  14  yr_built       21613 non-null  int64
#  15  yr_renovated   21613 non-null  int64
#  16  zipcode        21613 non-null  int64
#  17  lat            21613 non-null  float64
#  18  long           21613 non-null  float64
#  19  sqft_living15  21613 non-null  int64
#  20  sqft_lot15     21613 non-null  int64
# dtypes: float64(5), int64(15), object(1)
# memory usage: 3.5+ MB

# %% [markdown]
# ## isplay information (fields, datatypes, null values etc) about 'insurance' dataset

# %%
insurance.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1338 entries, 0 to 1337
# Data columns (total 8 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   index     1338 non-null   int64
#  1   age       1338 non-null   int64
#  2   sex       1338 non-null   object
#  3   bmi       1338 non-null   float64
#  4   children  1338 non-null   int64
#  5   smoker    1338 non-null   object
#  6   region    1338 non-null   object
#  7   charges   1338 non-null   float64
# dtypes: float64(2), int64(3), object(3)
# memory usage: 83.8+ KB

# %% [markdown]
# ## RELATIONAL PLOTS (numerical x numerical)

# %% [markdown]
# ## tips | relplot | total_bill vs tip - day

# %%
tips.columns
# Out:
# Index(['total_bill', 'tip', 'sex', 'smoker', 'day', 'time', 'size'], dtype='object')

# %%
sns.barplot(data=tips, x=tips['total_bill'], y=tips['day'], hue=tips['sex'])
# Out:
# <Axes: xlabel='total_bill', ylabel='day'>

# %% [markdown]
# ## tips | scatterplot | total_bill vs tip - day

# %%
sns.scatterplot(data=tips, x=tips['total_bill'], y=tips['day'], hue=tips['sex'])
# Out:
# <Axes: xlabel='total_bill', ylabel='day'>

# %% [markdown]
# ## tips | lineplot | total_bill vs tip - day

# %%
sns.lineplot(data=tips, x=tips['total_bill'], y=tips['day'], hue=tips['sex'])
# Out:
# <Axes: xlabel='total_bill', ylabel='day'>

# %% [markdown]
# ## Bank | scatterplot | NumOfProducts vs Age - Exited

# %%
bank.columns
# Out:
# Index(['Surname', 'CreditScore', 'Geography', 'Gender', 'Age', 'Tenure',
#        'Balance', 'NumOfProducts', 'HasCrCard', 'IsActiveMember',
#        'EstimatedSalary', 'Exited'],
#       dtype='object')

# %%
sns.scatterplot(data=bank, x=bank['NumOfProducts'], y=bank['Age'], hue=bank['Exited'])
# Out:
# <Axes: xlabel='NumOfProducts', ylabel='Age'>

# %% [markdown]
# ## Stroke | scatterplot | bmi vs age - stroke

# %%
stroke.columns
# Out:
# Index(['work_type', 'smoking_status', 'gender', 'ever_married',
#        'Residence_type', 'age', 'hypertension', 'heart_disease',
#        'avg_glucose_level', 'bmi', 'stroke'],
#       dtype='object')

# %%
sns.scatterplot(data=stroke, x=stroke['bmi'], y=stroke['age'], hue=stroke['gender'])
# Out:
# <Axes: xlabel='bmi', ylabel='age'>

# %% [markdown]
# ## House | scatterplot | sqft_living vs price

# %%
house.columns
# Out:
# Index(['id', 'date', 'price', 'bedrooms', 'bathrooms', 'sqft_living',
#        'sqft_lot', 'floors', 'waterfront', 'view', 'condition', 'grade',
#        'sqft_above', 'sqft_basement', 'yr_built', 'yr_renovated', 'zipcode',
#        'lat', 'long', 'sqft_living15', 'sqft_lot15'],
#       dtype='object')

# %%
sns.scatterplot(data=house, x=house['sqft_living'], y=house['price'], hue=house['floors'])
# Out:
# <Axes: xlabel='sqft_living', ylabel='price'>

# %% [markdown]
# ## Insurance | scatterplot | age vs charges - smoker

# %%
insurance.columns
# Out:
# Index(['index', 'age', 'sex', 'bmi', 'children', 'smoker', 'region',
#        'charges'],
#       dtype='object')

# %%
sns.scatterplot(data=insurance, x=insurance['age'], y=insurance['charges'], hue=insurance['smoker'])
# Out:
# <Axes: xlabel='age', ylabel='charges'>

# %% [markdown]
# ## CATEGORICAL PLOTS (categorical x numerical)

# %% [markdown]
# ## Stroke | stripplot | stroke vs age

# %%
sns.stripplot(x='stroke', y='age', data=stroke)
# Out:
# <Axes: xlabel='stroke', ylabel='age'>

# %% [markdown]
# ## Stroke | swarmplot | stroke vs age

# %%
sns.swarmplot(x='stroke', y='age',hue='gender', data=stroke)
# Out:
# <Axes: xlabel='stroke', ylabel='age'>

# %% [markdown]
# ## Stroke | boxplot | stroke vs age

# %%
sns.boxplot(x='stroke', y='age', data=stroke)
# Out:
# <Axes: xlabel='stroke', ylabel='age'>

# %% [markdown]
# ## Stroke | boxenplot | stroke vs age

# %%
sns.boxenplot(x='stroke', y='age', data=stroke)
# Out:
# <Axes: xlabel='stroke', ylabel='age'>

# %% [markdown]
# ## Stroke | violinplot | stroke vs age

# %%
sns.violinplot(x='stroke', y='age', data=stroke)
# Out:
# <Axes: xlabel='stroke', ylabel='age'>

# %% [markdown]
# ## REGRESSION PLOTS (numerical x numerical)

# %% [markdown]
# ## Stroke | lmplot | age vs bmi - stroke

# %%
sns.jointplot(data=stroke, x="age", y="bmi", hue="gender")

# %%
sns.scatterplot(x=stroke['age'],y=stroke['bmi'])
# Out:
# <Axes: xlabel='age', ylabel='bmi'>

# %%
sns.regplot(x=stroke['age'],y=stroke['bmi'])
# Out:
# <Axes: xlabel='age', ylabel='bmi'>

# %% [markdown]
# ## Tips | lmplot | total_bill vs tip - day

# %%
tips.columns
# Out:
# Index(['total_bill', 'tip', 'sex', 'smoker', 'day', 'time', 'size'], dtype='object')

# %%
sns.barplot(x=tips['day'],y=tips['total_bill'],hue=tips['sex'])
# Out:
# <Axes: xlabel='day', ylabel='total_bill'>

# %% [markdown]
# ## Tips | lmplot | total_bill vs tip

# %%
sns.scatterplot(x=tips['total_bill'],y=tips['tip'],data=tips)
# Out:
# <Axes: xlabel='total_bill', ylabel='tip'>

# %% [markdown]
# ## Tips | residplot | total_bill vs tip

# %%
sns.regplot(x=tips['total_bill'],y=tips['tip'],data=tips)
# Out:
# <Axes: xlabel='total_bill', ylabel='tip'>

# %% [markdown]
# ## Insurance | lmplot | age vs charges - smoker

# %%
insurance.columns
# Out:
# Index(['index', 'age', 'sex', 'bmi', 'children', 'smoker', 'region',
#        'charges'],
#       dtype='object')

# %%
sns.scatterplot(x=insurance['age'],y=insurance['charges'],data=insurance,hue=insurance['smoker'])
# Out:
# <Axes: xlabel='age', ylabel='charges'>

# %% [markdown]
# ## Insurance | regplot | age vs charges

# %%
sns.regplot(x=insurance['age'],y=insurance['charges'],data=insurance)
# Out:
# <Axes: xlabel='age', ylabel='charges'>

# %% [markdown]
# ## Insurance | residplot | age vs charges

# %%
sns.residplot(y="charges", x="age",data=insurance)
# Out:
# <Axes: xlabel='age', ylabel='charges'>

# %% [markdown]
# ## MATRIX PLOTS (table)

# %% [markdown]
# ## Bank | heatmap

# %%
 plt.subplots(figsize=(12, 5));
 sns.heatmap(bank.corr(), annot = True)
# Out:
# <Axes: >

# %% [markdown]
# ## Stroke | heatmap

# %%
 plt.subplots(figsize=(16, 8));
 sns.heatmap(stroke.corr(), annot = True)
# Out:
# <Axes: >

# %% [markdown]
# ## Telco | heatmap

# %%
plt.subplots(figsize=(16, 8));
sns.heatmap(telco.corr(), annot = True)
# Out:
# <Axes: >

# %% [markdown]
# ## House | heatmap

# %%
plt.subplots(figsize=(16, 8));
sns.heatmap(house.corr(), annot = True)
# Out:
# <Axes: >

# %% [markdown]
# ## Insurance | heatmap

# %%
plt.subplots(figsize=(16, 8));
sns.heatmap(insurance.corr(), annot = True)
# Out:
# <Axes: >

# %% [markdown]
# ## Bank | clustermap

# %%
sns.clustermap(bank.corr(), annot = True)

# %% [markdown]
# ## data = tips | plot = FacetGrid | x = total_bill | y = tip | row = sex | column = time

# %%
g=sns.FacetGrid(tips, col="time",  row="sex")
g.map(sns.scatterplot, x=tips['total_bill'], y=tips["tip"])

# %% [markdown]
# ## data = insurance | plot = FacetGrid | x = age | y = charges | row = smoker | column = gender

# %%
g=sns.FacetGrid(insurance, col="sex",  row="smoker")
g.map(sns.scatterplot, x=insurance['age'], y=insurance['charges'])

# %% [markdown]
# ## data = stroke | plot = FacetGrid | x = age | y = bmi | row = stroke | column = ever_married

# %%
stroke.columns
# Out:
# Index(['work_type', 'smoking_status', 'gender', 'ever_married',
#        'Residence_type', 'age', 'hypertension', 'heart_disease',
#        'avg_glucose_level', 'bmi', 'stroke'],
#       dtype='object')

# %%
g=sns.FacetGrid(stroke, col="ever_married",  row="stroke")
g.map(sns.scatterplot, x=stroke['age'], y=stroke['bmi'])

# %% [markdown]
# ## data = stroke | plot = jointplot | x = age | y = bmi

# %%
sns.jointplot(data=stroke, x="age", y="bmi")

# %% [markdown]
# ## data = insurance | plot = jointplot | x = age | y = charges

# %%
sns.jointplot(data=insurance, x="age", y="charges")

# %% [markdown]
# ## data = bank | plot = pairplot | x = 'CreditScore','Age','Tenure','Exited' | hue = Exited

# %%
bank.columns
# Out:
# Index(['Surname', 'CreditScore', 'Geography', 'Gender', 'Age', 'Tenure',
#        'Balance', 'NumOfProducts', 'HasCrCard', 'IsActiveMember',
#        'EstimatedSalary', 'Exited'],
#       dtype='object')

# %%
sns.pairplot(data=bank[['CreditScore','Age','Tenure','Exited']],hue='Exited',height=3, kind='scatter')

# %% [markdown]
# ## data = bank | plot = pairplot | x = 'Balance','NumOfProducts','HasCrCard','Exited' | hue = Exited

# %%
sns.pairplot(data=bank[['Balance','NumOfProducts','HasCrCard','Exited']],hue='Exited',height=3, kind='scatter')

# %% [markdown]
# ## data = bank | plot = pairplot | x = 'IsActiveMember','EstimatedSalary','Exited' | hue = Exited

# %%
sns.pairplot(data=bank[['IsActiveMember','EstimatedSalary','Exited']],hue='Exited',height=3, kind='scatter')

# %% [markdown]
# ## data = stroke | plot = pairplot | x = 'age','hypertension','heart_disease','stroke' | hue = stroke

# %%
sns.pairplot(data=stroke[['age','hypertension','heart_disease','stroke']],hue='stroke',height=3, kind='scatter')

# %% [markdown]
# ## data = stroke | plot = pairplot | x = 'avg_glucose_level','bmi','stroke' | hue = stroke

# %%
sns.pairplot(data=stroke[['avg_glucose_level','bmi','stroke']],hue='stroke',height=3, kind='scatter')

# %% [markdown]
# ## data = stroke | plot = histplot | x = 'bmi' | hue = stroke

# %%
sns.histplot(data=stroke, x="bmi", kde=True,hue='stroke')
# Out:
# <Axes: xlabel='bmi', ylabel='Count'>

# %% [markdown]
# ## SAMPLE DATASETS

# %%
sns.get_dataset_names()
# Out:
# ['anagrams',
#  'anscombe',
#  'attention',
#  'brain_networks',
#  'car_crashes',
#  'diamonds',
#  'dots',
#  'dowjones',
#  'exercise',
#  'flights',
#  'fmri',
#  'geyser',
#  'glue',
#  'healthexp',
#  'iris',
#  'mpg',
#  'penguins',
#  'planets',
#  'seaice',
#  'taxis',
#  'tips',
#  'titanic']

# %%
anagrams = sns.load_dataset('anagrams')
anagrams.head()
# Out:
#    subidr    attnr  num1  num2  num3
# 0       1  divided     2   4.0     7
# 1       2  divided     3   4.0     5
# 2       3  divided     3   5.0     6
# 3       4  divided     5   7.0     5
# 4       5  divided     4   5.0     8

# %%
planets = sns.load_dataset('planets')
planets.head()
# Out:
#             method  number  orbital_period   mass  distance  year
# 0  Radial Velocity       1         269.300   7.10     77.40  2006
# 1  Radial Velocity       1         874.774   2.21     56.95  2008
# 2  Radial Velocity       1         763.000   2.60     19.84  2011
# 3  Radial Velocity       1         326.030  19.40    110.62  2007
# 4  Radial Velocity       1         516.220  10.50    119.47  2009

# %%
titanic = sns.load_dataset('titanic')
titanic.head()
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked  class  \
# 0         0       3    male  22.0      1      0   7.2500        S  Third
# 1         1       1  female  38.0      1      0  71.2833        C  First
# 2         1       3  female  26.0      0      0   7.9250        S  Third
# 3         1       1  female  35.0      1      0  53.1000        S  First
# 4         0       3    male  35.0      0      0   8.0500        S  Third
#
#      who  adult_male deck  embark_town alive  alone
# 0    man        True  NaN  Southampton    no  False
# 1  woman       False    C    Cherbourg   yes  False
# 2  woman       False  NaN  Southampton   yes   True
# 3  woman       False    C  Southampton   yes  False
# 4    man        True  NaN  Southampton    no   True
